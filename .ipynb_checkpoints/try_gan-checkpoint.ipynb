# %%
# try to build a gan on the MNIST dataset

#import sklearn.datasets
from keras.models import Sequential
from keras.layers import Dense, Activation, Input, BatchNormalization
from keras.layers import advanced_activations
from keras.datasets import mnist

import keras
import keras.backend as K
from keras.optimizers import Adam
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# tips and tricks - https://github.com/soumith/ganhacks

# adapted from https://github.com/naokishibuya/deep-learning/blob/master/python/gan_mnist.ipynb

# %%
# hyperparameters
sample_size     = 100     # latent sample size (i.e., 100 random numbers)
g_hidden_size   = 128
d_hidden_size   = 128
leaky_alpha     = 0.01
g_learning_rate = 0.0001  # learning rate for the generator
d_learning_rate = 0.001   # learning rate for the discriminator
epochs          = 25
batch_size      = 16      # train batch size
eval_size       = 16      # evaluate size
smooth          = 0.1     # real images get class weight 1 - smooth to avoid overfitting

# %%
# HELPER FUNCTIONS

# generate latent vectors
def make_latent_samples(n_samples, sample_size):
    #return np.random.uniform(-1, 1, size=(n_samples, sample_size))
    return np.random.normal(loc=0, scale=1, size=(n_samples, sample_size))

# turn learning in the discriminator on and off during training
def make_trainable(model, trainable):
    for layer in model.layers:
        layer.trainable = trainable

# translate from 0 to 255 -> -1 to 1
def preprocess(x):    
    x = x.reshape(-1, 784) # 784=28*28
    x = np.float64(x)
    x = (x / 255 - 0.5) * 2
    x = np.clip(x, -1, 1)
    return x

# translate from -1 to 1 -> 0 to 255
def deprocess(x):
    x = (x / 2 + 1) * 255
    x = np.clip(x, 0, 255)
    x = np.uint8(x)
    x = x.reshape(28, 28)
    return x


def make_labels(size):
    return np.ones([size, 1]), np.zeros([size, 1])

# %%
# network construction logic

def make_simple_GAN(sample_size, 
                    g_hidden_size, 
                    d_hidden_size, 
                    leaky_alpha, 
                    g_learning_rate,
                    d_learning_rate):
    #K.clear_session()
    
    generator = Sequential([
        Dense(g_hidden_size, input_shape=(sample_size,)),
        advanced_activations.LeakyReLU(alpha=leaky_alpha),
        Dense(784),        
        Activation('tanh')
    ], name='generator')    

    discriminator = Sequential([
        Dense(d_hidden_size, input_shape=(784,)),
        advanced_activations.LeakyReLU(alpha=leaky_alpha),
        Dense(1),
        Activation('sigmoid')
    ], name='discriminator')    
    
    gan = Sequential([
        generator,
        discriminator
    ])
    
    discriminator.compile(optimizer=Adam(lr=d_learning_rate), loss='binary_crossentropy')
    gan.compile(optimizer=Adam(lr=g_learning_rate), loss='binary_crossentropy')
    
    return gan, generator, discriminator

# %%
# digits data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train_real = preprocess(X_train)
X_test_real = preprocess(X_test)

# %%
# check out some training images

# a handful of examples
plt.figure(figsize=(5, 4))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

# just 1 example
sample = X_train[17]

plt.figure(figsize=(3, 2))
plt.title(sample.shape)
plt.imshow(sample, cmap='gray')
plt.colorbar()
plt.show()

# check out the grayscale range ( values from 0 to 255)
X_train.min(), X_train.max()

# verify the proprocessing step
plt.figure(figsize=(5, 4))
for i in range(20):
    img = deprocess(X_train_real[i])
    plt.subplot(4, 5, i+1)
    plt.imshow(img, cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

X_train_real.min(), X_train_real.max()
print(np.shape(X_train_real[17]))
# Out:
# (784L,)

# %%
# Out:
# "\ndiscriminator = Sequential([\n    Dense(128, input_shape=(784,)),\n    advanced_activations.LeakyReLU(alpha=0.01),\n    Dense(1),\n    Activation('sigmoid')\n], name='discriminator')\n\ndiscriminator.summary()\n"

# %%
# Out:
# '\ngan = Sequential([\n    generator,\n    discriminator\n])\n\ngan.summary()\n'

# %%
# Out:
# "'\n# at first, during training, don't update weights in the discriminator\nmake_trainable(discriminator, False)\n\n# set up the networks\ndiscriminator.compile(optimizer=Adam(lr=d_learning_rate), loss='binary_crossentropy')\ngan.compile(optimizer=Adam(lr=g_learning_rate), loss='binary_crossentropy')\n\n"

# %%
# labels for the batch size and the test size
y_train_real, y_train_fake = make_labels(batch_size)
y_eval_real,  y_eval_fake  = make_labels(eval_size)


# create a GAN, a generator and a discriminator
gan, generator, discriminator = make_simple_GAN(
    sample_size, 
    g_hidden_size, 
    d_hidden_size, 
    leaky_alpha, 
    g_learning_rate,
    d_learning_rate)


losses = []
for e in range(epochs):
    for i in range(len(X_train_real)//batch_size):
        # real MNIST digit images
        X_batch_real = X_train_real[i*batch_size:(i+1)*batch_size]
        
        # latent samples and the generated digit images
        latent_samples = make_latent_samples(batch_size, sample_size)
        X_batch_fake = generator.predict_on_batch(latent_samples)
        
        # train the discriminator to detect real and fake images
        make_trainable(discriminator, True)
        discriminator.train_on_batch(X_batch_real, y_train_real * (1 - smooth))
        discriminator.train_on_batch(X_batch_fake, y_train_fake)

        # train the generator via GAN
        make_trainable(discriminator, False)
        gan.train_on_batch(latent_samples, y_train_real)
        
        
     # evaluate
    X_eval_real = X_test_real[np.random.choice(len(X_test_real), eval_size, replace=False)]
    
    latent_samples = make_latent_samples(eval_size, sample_size)
    X_eval_fake = generator.predict_on_batch(latent_samples)

    d_loss  = discriminator.test_on_batch(X_eval_real, y_eval_real)
    d_loss += discriminator.test_on_batch(X_eval_fake, y_eval_fake)
    g_loss  = gan.test_on_batch(latent_samples, y_eval_real) # we want the fake to be realistic!
    
    losses.append((d_loss, g_loss))
    
    print("Epoch: {}/{} Discriminator Loss: {} Generator Loss: {}".format(e+1, epochs, d_loss, g_loss))
# Out:
# Epoch: 1/25 Discriminator Loss: 0.92156291008 Generator Loss: 2.04704332352
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-5ecc0a905c94> in <module>()
#      31         # train the generator via GAN
#      32         make_trainable(discriminator, False)
# ---> 33         gan.train_on_batch(latent_samples, y_train_real)
#      34
#      35
#
# c:\users\brendan\anaconda\lib\site-packages\keras\models.pyc in train_on_batch(self, x, y, class_weight, sample_weight)
#     953         return self.model.train_on_batch(x, y,
#     954                                          sample_weight=sample_weight,
# --> 955                                          class_weight=class_weight)
#     956
#     957     def test_on_batch(self, x, y,
#
# c:\users\brendan\anaconda\lib\site-packages\keras\engine\training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1760             ins = x + y + sample_weights
#    1761         self._make_train_function()
# -> 1762         outputs = self.train_function(ins)
#    1763         if len(outputs) == 1:
#    1764             return outputs[0]
#
# c:\users\brendan\anaconda\lib\site-packages\keras\backend\theano_backend.pyc in __call__(self, inputs)
#    1220     def __call__(self, inputs):
#    1221         assert isinstance(inputs, (list, tuple))
# -> 1222         return self.function(*inputs)
#    1223
#    1224
#
# c:\users\brendan\anaconda\lib\site-packages\theano\compile\function_module.pyc in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# c:\users\brendan\anaconda\lib\site-packages\theano\gof\op.pyc in rval(p, i, o, n)
#     870             # default arguments are stored in the closure of `rval`
#     871             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 872                 r = p(n, [x[0] for x in i], o)
#     873                 for o in node.outputs:
#     874                     compute_map[o][0] = True
#
# c:\users\brendan\anaconda\lib\site-packages\theano\tensor\blas.pyc in perform(self, node, inp, out)
#    1813         z, = out
#    1814         try:
# -> 1815             z[0] = numpy.asarray(scalar * numpy.dot(x, y))
#    1816         except ValueError as e:
#    1817             # The error raised by numpy has no shape information, we
#
# KeyboardInterrupt:

# %%
# plot the training results

losses = np.array(losses)

fig, ax = plt.subplots()
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()
plt.show()

# %%
# take a look at some examples

latent_samples = make_latent_samples(20, sample_size)
generated_digits = generator.predict(latent_samples)

plt.figure(figsize=(10, 8))
for i in range(20):
    img = deprocess(generated_digits[i])
    plt.subplot(4, 5, i+1)
    plt.imshow(img, cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()
